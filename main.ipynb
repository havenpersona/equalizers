# %%
# %run main.py --order first --f_type allpass
# Out:
# the shape of w is  (512,)

# %%
# %run main.py --order first --f_type low --boost Yes
# Out:
# the shape of w is  (512,)

# %%
# %run main.py --order first --f_type low --boost No
# Out:
# the shape of w is  (512,)

# %%
# %run main.py --order first --f_type high --boost Yes
# Out:
# the shape of w is  (512,)

# %%
 # %run main.py --order first --f_type high --boost No
# Out:
# the shape of w is  (512,)

# %%
# %run main.py --order second --f_type peak --boost Yes
# Out:
# the shape of w is  (512,)

# %%
 # %run main.py --order second --f_type peak --boost No
# Out:
# the shape of w is  (512,)

# %%
# %run main.py --order second --f_type low --boost Yes
# Out:
# the shape of w is  (512,)

# %%
# %run main.py --order second --f_type low --boost No
# Out:
# the shape of w is  (512,)

# %%
# %run main.py --order second --f_type high --boost Yes
# Out:
# the shape of w is  (512,)

# %%
# %run main.py --order second --f_type high --boost No
# Out:
# the shape of w is  (512,)
